# %%
import numpy as np

# %% [markdown]
# QUESTION 1
# ==========

# %% [markdown]
# Academic Honesty Pledge
# Cal Poly PHYS 202 - Spring 2013
# I have read and understand the rules regarding academic honesty and I agree to abide by them. I pledge on my honor that I have not given or received any unauthorized assistance on assignments or ex- aminations in this course.
# Signed: Jordan Runco
# Dated: 5/7/13
#
# also added to git hub

# %% [markdown]
# QUESTION 2
# ==========

# %% [markdown]
# part a

# %%
import math

# %%
theta = arange(-pi,pi,.1)
plot(theta,(cos(2*theta)*cos(theta/2))**2, color = "red")
xlabel(r"$\theta$" " (rad)")
ylabel("intensity")
xticks( [-np.pi, -np.pi/2, -np.pi/4, 0, np.pi/4, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$-\pi/4$', r'$0$', r'$\pi/4$', r'$+\pi/2$', r'$+\pi$'])
show()

# %%
theta = arange(-pi,pi,.1)
plot(theta,(cos(2*theta)*cos(theta/2))**2, linestyle = "*", linewidth = 6) #NEED TO FIND STAR LINESTYLE
xlabel(r"$\theta$" " (rad)")
ylabel("intensity")
xticks( [-np.pi, -np.pi/2, -np.pi/4, 0, np.pi/4, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$-\pi/4$', r'$0$', r'$\pi/4$', r'$+\pi/2$', r'$+\pi$'])
show()
# get correct graph but can't find star linestyle

# %%
# same graph as above to show i have it correct except for the star linestyle
theta = arange(-pi,pi,.1)
plot(theta,(cos(2*theta)*cos(theta/2))**2, linestyle = ":", linewidth = 6) #NEED TO FIND STAR LINESTYLE
xlabel(r"$\theta$" " (rad)")
ylabel("intensity")
xticks( [-np.pi, -np.pi/2, -np.pi/4, 0, np.pi/4, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$-\pi/4$', r'$0$', r'$\pi/4$', r'$+\pi/2$', r'$+\pi$'])
show()
# get correct graph but can't find star linestyle

# %% [markdown]
# part b

# %%
f = lambda x: (x+1)/(x-1)
g = lambda x: exp(-x)
x = arange(-4,4,.1)
plot(x,f(x), color = "blue", label = '(t+1)/(t-1)')
plot(x,g(x), linestyle = ':', color = "red", label = "exp(-t)")
xlabel("time (seconds)")
ylabel("f(t),g(t)")
legend(loc = "lower left")
ylim(-10,10)
annotate('discontinuous here', xy=(2.5,f(2.5)), xytext=(1, -3.),)
show()

# %% [markdown]
# QUESTION 3
# ==========

# %% [markdown]
# part a

# %%
from Electrostatics import *
from scipy import integrate

# %% [markdown]
# part b

# %%
def pointField(x,y,q,Xq,Yq):
    q = 1e-6
    a = 1.
    b = 2.0
    Xq = 3
    Yq = 3
    answer = integrate.quad(pointField(x,y,q,Xq,Yq), a, b)
    return answer
print pointField(x,y,q,Xq,Yq)
#ran out of time
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-899e4adf5a94> in <module>()
#       7     answer = integrate.quad(pointField(x,y,q,Xq,Yq), a, b)
#       8     return answer
# ----> 9 print pointField(x,y,q,Xq,Yq)
#      10 #ran out of time
#      11
#
# NameError: name 'y' is not defined

# %% [markdown]
# QUESTION 4
# ==========

# %% [markdown]
# part a

# %%
prefixes = 'JKLMNOPQ' #original code
suffix = 'ack'

for letter in prefixes:
    print letter + suffix
# Out:
# Jack
# Kack
# Lack
# Mack
# Nack
# Oack
# Pack
# Qack

# %%
"""MODIFIED CODE"""
prefixes = 'JKLMNOPQ'
suffix = 'ack'

for letter in prefixes:
    if letter == "O" or letter == "Q": #if the first letter is an O or a Q, add a u after it
        print letter + "u" + suffix
    else: # if not, don't add a u
        print letter + suffix
# Out:
# Jack
# Kack
# Lack
# Mack
# Nack
# Ouack
# Pack
# Quack

# %% [markdown]
# part b

# %%
def is_anagram(s1,s2):
    #ran out of time
