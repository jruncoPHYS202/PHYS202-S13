# %%
l = w = 4.
r = 1.375
Nin = 15
N = 40
Aboard = l*w
Aexact = pi*r**2
Acirc = (Nin/float(N))*Aboard #since we calculate a ratio, make sure the are floats
print "Aboard=", Aboard
print "Aexact=", Aexact
print "Acirc=", Acirc
print "Error=", (100.*(Acirc-Aexact)/Aexact),"%"
# Out:
# Aboard= 16.0
# Aexact= 5.93957361069
# Acirc= 6.0
# Error= 1.01735230957 %

# %% [markdown]
# EXAMPLE 1
# =========

# %% [markdown]
# step 1

# %%
f = lambda x: x**(.5) + sin(x)

# %%
x = arange(0.,15.,.001)

# %%
myplot = plot(x,f(x), lw = 3)
ylabel(r'$x^{1/2} + \sin(x)$', fontsize=20 )
xlabel(r'$x$', fontsize=20)
xlim(0.,15.)
show()

# %% [markdown]
# step 2

# %%
xmin = 1.7
xmax = 12.4

#fint the maximum value of f within the boundary to set ymax
subx = x[logical_and((x > xmin),(x < xmax))]
ymax = max(f(subx))*1.05
ymin = 0.

#replot the function
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

#plot the box
plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--') #vertical left
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--') #vertical right
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--') #horizontal top
show()

# %% [markdown]
# step 3

# %%
#random_sample?

N = 10000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

#Replot the function
myplot = plot(x,f(x), lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')

#plot the box
plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--') #vertical left
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--') #vertical right
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--') #horizontal top
show()

# %%
newmask = (samples_y < f(samples_x))

# %%
sum(newmask)
# Out:
# 6226

# %%
#replot the function
myplot = plot(x,f(x), lw=3)
xlim(0., 15.)

plot(samples_x[1:200],samples_y[1:200],'.')

#show the ones below the function in red
plot(samples_x[newmask[:200]],samples_y[newmask[:200]],'r.')

#plot da box AGAIN
plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--') #vert left
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--') #vert right
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--') #horiz top
show()

# %%
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.7084939604

# %%
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100*(Iexact-I)/Iexact
print "I_exact=", Iexact
print "I_hitormiss=", I
print "Error on I =", Ierr,"%"
# Out:
# I_exact= 26.5172145362
# I_hitormiss= 26.7084939604
# Error on I = -0.721340561397 %

# %% [markdown]
# EXCERSICE 1
# ===========

# %% [markdown]
# change N so the error of the result is within .001%

# %%
f = lambda x: x**(.5) + sin(x)

# %%
x = arange(0.,15.,.001)

# %%
xmin = 1.7
xmax = 12.4

#fint the maximum value of f within the boundary to set ymax
subx = x[logical_and((x > xmin),(x < xmax))]
ymax = max(f(subx))*1.05
ymin = 0.

#replot the function
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

#plot the box
plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--') #vertical left
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--') #vertical right
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--') #horizontal top
show()

# %%
#random_sample?

N = 10000 #INCREASED N
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

#Replot the function
myplot = plot(x,f(x), lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')

#plot the box
plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--') #vertical left
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--') #vertical right
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--') #horizontal top
show()

# %%
newmask = (samples_y < f(samples_x))
sum(newmask)
# Out:
# 6142

# %%
#replot the function
myplot = plot(x,f(x), lw=3)
xlim(0., 15.)

plot(samples_x[1:200],samples_y[1:200],'.')

#show the ones below the function in red
plot(samples_x[newmask[:200]],samples_y[newmask[:200]],'r.')

#plot da box AGAIN
plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--') #vert left
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--') #vert right
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--') #horiz top
show()

# %%
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.3481480734

# %%
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100*(Iexact-I)/Iexact
print "I_exact=", Iexact
print "I_hitormiss=", I
print "Error on I =", Ierr,"%"
# Out:
# I_exact= 26.5172145362
# I_hitormiss= 26.3481480734
# Error on I = 0.637572481834 %

# %% [markdown]
# EXERCISE 2
# ==========

# %% [markdown]
# part a

# %%
myplot = plot(x,f(x),lw=3)
xlabel(r'$x$', fontsize=20)
ylabel(r'$x^{1/2} + \sin(x)$',fontsize=20)
xlim(0.,15.)

#random sample?
N = 10000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

#replot the function
myplot = plot(x,f(x), lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')

#plot the box
plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--') #vertical left
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--') #vertical right
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--') #horizontal top
show()

# %% [markdown]
# part b

# %% [markdown]
# part c

# %% [markdown]
# EXAMPLE 2
# =========

# %%
# integrating 3 dimensions over a box
fxyz = lambda x,y,z: sqrt(x**2 + y**2 + z**2)

N = 1e6
L = 1.; W=1; H=1.
x = L*random_sample(N); y = W*random_sample(N); z = H*random_sample(N);

IntMC = (L*W*H/N)*sum(fxyz(x,y,z))

# %%
N = 10000
fsph = lambda r,phi: (cos(phi)/r**3)

phimax = 2*pi; thetamax = pi; rmax = 1;
phi = phimax*random_sample(N)
theta = thetamax*random_sample(N)
r = rmax*random_sample(N)
Integral_MC = (phimax*thetamax*rmax/N)*sum(fsph(r,phi)*r**2*sin(theta))

# %% [markdown]
# EXAMPLE 3: Electric potential of a plane with constant charge density

# %%
# add week3 directory to search path
import sys
sys.path.insert(0, '../week3')

# import out point potential function
from Electrostatics import *

#define our variables
sigma = 1e-6; # charge density is 1.0 microC/m^2
N = 1e6;
x0 = 2.; # P(x0,y0)
y0 = 3.;
xi = -1. + 2.001*random_sample(N); # -1<x<1 integration limits
yi = 0. + 2.001*random_sample(N); # 0<y<2 integration limits

#electric potential at P from a chunk of charge at xi, yi
Vi = pointPotential(x0, y0, sigma, xi, yi);

#integration Vi for chunks of charge in x and y directions
Vtot = (2.*2./N)*sum(Vi) # range is 2 in x and y
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-30bcb4d92fdc> in <module>()
#       4
#       5 # import out point potential function
# ----> 6 from Electrostatics import *
#       7
#       8 #define our variables
#
# ImportError: No module named Electrostatics
