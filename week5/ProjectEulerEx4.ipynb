# %% [markdown]
# 1000 * 1000 = 1000000
#
# This has 7 digits so largest palindrome must have 6 digits max

# %%
def largest_palindrome():
    """ Finds the largest palindrome made from two three digit numbers (100-999)"""
    palindrome_list = [] #empty list. code will add possible palindrome values to list
    for y in range(100,1000): # range of possible y values
        for x in range (100,1000): # range of possible y values
            product = str(x*y) #turns the product into a string which can go in a list
            if len(product) == 6 and product[0] == product[5] and product[1] == product[4] and product[2] == product[3]:
                """if the number qualifies as a palindrome"""
                palindrome_list.append(product) # add it to palindrom_list
    return palindrome_list #return the list
print largest_palindrome() #print the list of palindromes
# Out:
# ['106601', '119911', '117711', '110011', '105501', '101101', '111111', '121121', '131131', '141141', '108801', '143341', '102201', '165561', '155551', '127721', '133331', '168861', '174471', '180081', '142241', '102201', '137731', '154451', '171171', '189981', '204402', '210012', '188881', '182281', '108801', '111111', '138831', '141141', '168861', '171171', '198891', '219912', '222222', '219912', '128821', '201102', '214412', '227722', '171171', '215512', '105501', '133331', '161161', '178871', '221122', '238832', '210012', '111111', '222222', '117711', '213312', '219912', '234432', '255552', '239932', '122221', '244442', '111111', '141141', '171171', '222222', '252252', '220022', '201102', '270072', '202202', '212212', '222222', '232232', '242242', '252252', '262262', '272272', '282282', '198891', '239932', '234432', '219912', '252252', '234432', '161161', '168861', '123321', '156651', '189981', '213312', '246642', '279972', '225522', '256652', '212212', '219912', '232232', '239932
# ...

# %%
""" Now to find the largest palindrome in this list."""
def largest_palindrome(): #same code as above without the print statement
    """ Finds the largest palindrome made from two three digit numbers (100-999)"""
    palindrome_list = [] #empty list. code will add possible palindrome values to list
    for y in range(100,1000): # range of possible y values
        for x in range (100,1000): # range of possible y values
            product = str(x*y) #turns the product into a string which can go in a list
            if len(product) == 6 and product[0] == product[5] and product[1] == product[4] and product[2] == product[3]:
                """if the number qualifies as a palindrome"""
                palindrome_list.append(product) # add it to palindrom_list
    variable = 0 #create a variable to find largest palindrome. originally set it equal to zero but will change.
    for i in palindrome_list: #take every number in list and compare it to variable
        if variable < int(i): 
            variable = int(i)  
            """if variable is larger than i, set variable equal to i. loops through whole list to set variable equal to largest index i of list"""
    return variable

# %%
print largest_palindrome()
# Out:
# 906609

# %% [markdown]
# The largest palindrome created by multiplying two three digit numbers together is 906609
# ========================================================================================
