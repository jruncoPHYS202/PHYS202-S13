# %% [markdown]
# Electric dipole potential

# %% [markdown]
# \begin{equation}
# V(x,y) = \frac{kq}{\sqrt{x^{2} + (y-d)^{2}}} - \frac{kq}{\sqrt{x^{2} + (y+d)^{2}}}
# \end{equation}

# %%
#make the x-y grid to cover the plane -2<x<2 and -2<y<2
dx = .06
dy = .06
x,y = meshgrid(arange(-2.,2.,dx),arange(-2.,2.,dy))
x.ndim
y.shape
# Out:
# (67, 67)

# %%
k = 1; q = 1; d = 1
V = (k*q/(x**2 + (y - d)**2)**(1/2.) - (k*q/(x**2 + (y+d)**2)**(1/2.)))
print V
# Out:
# [[-0.1698635  -0.17826925 -0.18715865 ..., -0.19336737 -0.18414007
#   -0.17541494]
#  [-0.17127992 -0.17998007 -0.18920149 ..., -0.19565471 -0.18606779
#   -0.17702367]
#  [-0.17245961 -0.18144664 -0.19099347 ..., -0.19768747 -0.18774672
#   -0.17839056]
#  ...,
#  [ 0.17310174  0.18227437  0.19203282 ...,  0.19888408  0.18871243
#    0.17915368]
#  [ 0.17209427  0.1809867   0.19042599 ...,  0.19704029  0.18721662
#    0.1779635 ]
#  [ 0.17083282  0.17943553  0.18854686 ...,  0.19491887  0.18545135
#    0.17651294]]

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection = '3d')
p = ax.plot_surface(x,y,V, rstride=1, cstride=1, linewidth=0, cmap=cm.spectral) # cm. then hit tab

# %%
help(Axes3D.plot_surface)
# Out:
# Help on method plot_surface in module mpl_toolkits.mplot3d.axes3d:
#
# plot_surface(self, X, Y, Z, *args, **kwargs) unbound mpl_toolkits.mplot3d.axes3d.Axes3D method
#     Create a surface plot.
#
#     By default it will be colored in shades of a solid color,
#     but it also supports color mapping by supplying the *cmap*
#     argument.
#
#     ============= ================================================
#     Argument      Description
#     ============= ================================================
#     *X*, *Y*, *Z* Data values as 2D arrays
#     *rstride*     Array row stride (step size)
#     *cstride*     Array column stride (step size)
#     *color*       Color of the surface patches
#     *cmap*        A colormap for the surface patches.
#     *facecolors*  Face colors for the individual patches
#     *norm*        An instance of Normalize to map values to colors
#     *vmin*        Minimum value to map
#     *vmax*        Maximum value to map
# ...

# %%
levels = array([8, 4, 2, 1, .5, .25, 0, -.25, -.5, -1, -2, -4, -8])
contour(x,y,V,levels,cmap=cm.coolwarm)
show()

# %% [markdown]
# QUESTION 1
# \begin{equation}
# G(x,y) = e^{-x^{2}-y^{2}}
# \end{equation}

# %%
from mpl_toolkits.mplot3d import Axes3D
dx = 0.23
dy = 0.23
x,y = meshgrid(arange(-6.,6.,dx),arange(-6.,6.,dy))
G = e**(-x**2 - y**2)
x.ndim
y.shape
fig = figure()
ax = fig.gca(projection = '3d')
p = ax.plot_surface(x,y,G, rstride=1, cstride=1, linewidth=0, cmap=cm.spectral) # cm. then hit tab

levels = array([8, 4, 2, 1, .5, .25, 0, -.25, -.5, -1, -2, -4, -8])
cset = ax.contour(x, y, G, zdir='x', offset=-6,cmap=cm.spectral)
show()

# %% [markdown]
# QUESTION 2

# %%
from mpl_toolkits.mplot3d import Axes3D
k = 8.9875518*10**9 #N m^2/C^2
q1 = -1*10**-9 #C
q2 = -1*10**-9 #C
d = 1
V1 = (k*q1/((x+2)**2 + (y - d)**2)**(1/2.) - (k*q1/(x**2 + (y + 2 + d)**2)**(1/2.)))
V2 = (k*q2/((x-2)**2 + (y - d)**2)**(1/2.) - (k*q2/(x**2 + (y - 2 + d)**2)**(1/2.)))
  
dx = 0.08
dy = 0.08
x,y = meshgrid(arange(-4.,4.,dx),arange(-4.,4.,dy))
x.ndim
y.shape
levels = array([4., 2., 1., .5, .25, 0., -.25, -.5, -1., -2., -4.])
fig = figure()
ax = fig.gca(projection = '3d')
p = ax.plot_surface(x,y,V1, rstride=1, cstride=1, linewidth=0, cmap=cm.coolwarm) # cm. then hit tab
p = ax.plot_surface(x,y,V2, rstride=1, cstride=1, linewidth=0, cmap=cm.spectral)

# %% [markdown]
# QUESTION 3

# %% [markdown]
# part a

# %%
def pointPotential(x,y,q,posx,posy):
    k = 8.9875518*10**9 #setting k, q, and d values
    q = 1*10**-9
    d=1
    Vyx = (k*q)/(x**2 + y**2)**(1/2.) #insert Vxy function
    return Vyx #return Vxy

x,y = meshgrid(arange(-2.,2.,0.06),arange(-2.,2.,0.06))
Vyx = pointPotential(x,y,1e-9,0.,0.) 
print Vyx
# Out:
# [[ 3.17757941  3.22559495  3.27428946 ...,  3.30710904  3.25798498
#    3.20951244]
#  [ 3.22559495  3.27585506  3.32689793 ...,  3.36134185  3.30979899
#    3.25901295]
#  [ 3.27428946  3.32689793  3.38040363 ...,  3.41655455  3.36247083
#    3.30926048]
#  ...,
#  [ 3.30710904  3.36134185  3.41655455 ...,  3.45389067  3.3980434
#    3.3431539 ]
#  [ 3.25798498  3.30979899  3.36247083 ...,  3.3980434   3.34482043
#    3.29243068]
#  [ 3.20951244  3.25901295  3.30926048 ...,  3.3431539   3.29243068
#    3.24242797]]

# %% [markdown]
# part b

# %%
def dipolePotential(x,y,q,d):
    k = 8.9875518*10**9 #setting k, q, and d values
    q = 1*10**-9
    d=1
    Vxy = (k*q/((x)**2 + (y - d)**2)**(1/2.) - (k*q/(x**2 + (y + d)**2)**(1/2.))) #insert Vxy function
    return Vxy #return Vxy

x,y = meshgrid(arange(-2.,2.,0.06),arange(-2.,2.,0.06))
Vxy = dipolePotential(x,y,q,d) 
print Vxy
# Out:
# [[-1.52665698 -1.6022041  -1.68209807 ..., -1.73789923 -1.65496846
#   -1.57655087]
#  [-1.53938717 -1.61758022 -1.70045818 ..., -1.7584568  -1.67229388
#   -1.59100937]
#  [-1.54998969 -1.63076109 -1.71656371 ..., -1.77672638 -1.6873834
#   -1.60329437]
#  ...,
#  [ 1.55576088  1.63820032  1.72590493 ...,  1.78748094  1.69606276
#    1.61015302]
#  [ 1.54670621  1.6266273   1.71146343 ...,  1.77090977  1.68261909
#    1.59945622]
#  [ 1.53536885  1.61268616  1.69457464 ...,  1.75184346  1.66675364
#    1.5864192 ]]

# %% [markdown]
# part c

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection = '3d')
p = ax.plot_surface(x,y,Vyx, rstride=1, cstride=1, linewidth=0, cmap=cm.Blues)

# %%
def dipolePotential(x,y,q,d):
    k = 8.9875518*10**9 #setting k, q, and d values
    q = 1*10**-9
    d=1
    Vxy = (k*q/((x)**2 + (y - d)**2)**(1/2.) - (k*q/(x**2 + (y + d)**2)**(1/2.))) #insert Vxy function
    return Vxy #return Vxy

x,y = meshgrid(arange(-2.,2.,0.06),arange(-2.,2.,0.06))
Vxy = dipolePotential(x,y,q,d) 

from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection = '3d')
p = ax.plot_surface(x,y,Vxy, rstride=1, cstride=1, linewidth=0, cmap=cm.spectral) # cm. then hit tab
