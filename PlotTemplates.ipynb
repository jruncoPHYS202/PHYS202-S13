# %%
import numpy as np

# %% [markdown]
# PROBLEM 5
#
#
# part a

# %% [markdown]
# Publication ready plot template
# ===============================
#
#
# Simple graphing template for matplotlib functions and data plots.

# %% [markdown]
# part b

# %% [markdown]
# Line Plots

# %% [markdown]
# part c

# %%
y = arange(-5.0,5.0+1.0,1.0) # Define y and its range
E = np.array(cosh(y)) #write out equation
print E #print equation
p = np.array(sinh(y))
print p
# Out:
# [ 74.20994852  27.30823284  10.067662     3.76219569   1.54308063   1.
#    1.54308063   3.76219569  10.067662    27.30823284  74.20994852]
# [-74.20321058 -27.2899172  -10.01787493  -3.62686041  -1.17520119   0.
#    1.17520119   3.62686041  10.01787493  27.2899172   74.20321058]

# %% [markdown]
# part d

# %%
plot(y,E)
plot(y,p)

ax = gca()
ax.spines['right'].set_color('none') 
ax.spines['top'].set_color('none')
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))
ax.spines['top'].set_position(('data', 0))
ax.spines['right'].set_position(('data', -1))
xlabel("                                                                                                                      x")
ylabel("                                                                               y")

# %% [markdown]
# part e

# %% [markdown]
# Subplots

# %%
subplot(1,2,1); plot(y,E) #2,1,1 and 1,2,2 for on top of each other
title('Cosh')
subplot(1,2,2); plot(y,p) #Plotting sinh and cosh
title('Sinh') #subplot(m,n,P) creates an MxN matrix, and places the following plot in the P position 

ax = gca() #ax = gca needed to modify axes
ax.spines['right'].set_color('none')#deleting boundaries
ax.spines['top'].set_color('none')
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))
ax.spines['top'].set_position(('data', 0))
ax.spines['right'].set_position(('data', -1))
xlabel("x-axis")
ylabel("y-axis")

# %% [markdown]
# part e #2

# %%
n = 200
X = random.normal(0,1,n)
Y = random.normal(0,1,n)
plot(X,Y)

ax = gca() #ax = needed to modify axes
ax.spines['right'].set_color('none') #deleting boundaries
ax.spines['top'].set_color('none')
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))
ax.spines['top'].set_position(('data', 0))
ax.spines['right'].set_position(('data', -1))
xlabel("x-axis")
ylabel("y-axis")
